# %%
# !pip install langgraph langchain-openai
# !pip install langchain openai langchain-community
# Out:
# Requirement already satisfied: langgraph in c:\users\tae54\cat_llm\catllm\lib\site-packages (0.6.7)
# Requirement already satisfied: langchain-openai in c:\users\tae54\cat_llm\catllm\lib\site-packages (0.3.33)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langgraph) (0.3.76)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langgraph) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langgraph) (0.6.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langgraph) (0.2.6)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langgraph) (2.11.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.3)
# Requirement already satisfied: openai<2.0.0,>=1.104.2 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-openai) (1.107.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-openai) (0.11.0)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-core>=0.1->langgraph) (0.4.27)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.104.2->langchain-openai) (3.10)
# Requirement already satisfied: certifi in c:\users\tae54\cat_llm\catllm\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\tae54\cat_llm\catllm\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2025.9.1)
# Requirement already satisfied: requests>=2.26.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.5.0)
# Requirement already satisfied: colorama in c:\users\tae54\cat_llm\catllm\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.104.2->langchain-openai) (0.4.6)
# Collecting langchain
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: openai in c:\users\tae54\cat_llm\catllm\lib\site-packages (1.107.2)
# Collecting langchain-community
#   Downloading langchain_community-0.3.29-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain) (0.3.76)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Downloading langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain) (0.4.27)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain) (2.11.9)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.43-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.2.4-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: httpcore==1.* in c:\users\tae54\cat_llm\catllm\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Using cached aiohttp-3.12.15-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Collecting dataclasses-json<0.7,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting numpy>=2.1.0 (from langchain-community)
#   Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached frozenlist-1.7.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached multidict-6.6.4-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached propcache-0.3.2-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached yarl-1.20.1-cp313-cp313-win_amd64.whl.metadata (76 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\tae54\cat_llm\catllm\lib\site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: colorama in c:\users\tae54\cat_llm\catllm\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 17.9 MB/s  0:00:00
# Downloading langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Downloading sqlalchemy-2.0.43-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 37.2 MB/s  0:00:00
# Downloading langchain_community-0.3.29-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 46.1 MB/s  0:00:00
# Using cached aiohttp-3.12.15-cp313-cp313-win_amd64.whl (449 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached multidict-6.6.4-cp313-cp313-win_amd64.whl (45 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.20.1-cp313-cp313-win_amd64.whl (86 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached frozenlist-1.7.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading greenlet-3.2.4-cp313-cp313-win_amd64.whl (299 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------------------------- -------------- 8.1/12.8 MB 61.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.8 MB 28.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 28.2 MB/s  0:00:00
# Using cached propcache-0.3.2-cp313-cp313-win_amd64.whl (40 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, propcache, numpy, mypy-extensions, multidict, marshmallow, httpx-sse, greenlet, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-text-splitters, langchain, langchain-community
#
#    - --------------------------------------  1/21 [propcache]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --- ------------------------------------  2/21 [numpy]
#    --------- ------------------------------  5/21 [marshmallow]
#    --------- ------------------------------  5/21 [marshmallow]
#    ------------- --------------------------  7/21 [greenlet]
#    ------------- --------------------------  7/21 [greenlet]
#    ----------------- ----------------------  9/21 [attrs]
#    ------------------- -------------------- 10/21 [aiohappyeyeballs]
#    -------------------- ------------------- 11/21 [yarl]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ------------------------ --------------- 13/21 [SQLAlchemy]
#    ---------------------------- ----------- 15/21 [pydantic-settings]
#    ---------------------------- ----------- 15/21 [pydantic-settings]
#    -------------------------------- ------- 17/21 [aiohttp]
#    -------------------------------- ------- 17/21 [aiohttp]
#    -------------------------------- ------- 17/21 [aiohttp]
#    -------------------------------- ------- 17/21 [aiohttp]
#    -------------------------------- ------- 17/21 [aiohttp]
#    -------------------------------- ------- 17/21 [aiohttp]
#    ---------------------------------- ----- 18/21 [langchain-text-splitters]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    ------------------------------------ --- 19/21 [langchain]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    -------------------------------------- - 20/21 [langchain-community]
#    ---------------------------------------- 21/21 [langchain-community]
#
# Successfully installed SQLAlchemy-2.0.43 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 attrs-25.3.0 dataclasses-json-0.6.7 frozenlist-1.7.0 greenlet-3.2.4 httpx-sse-0.4.1 langchain-0.3.27 langchain-community-0.3.29 langchain-text-splitters-0.3.11 marshmallow-3.26.1 multidict-6.6.4 mypy-extensions-1.1.0 numpy-2.3.3 propcache-0.3.2 pydantic-settings-2.10.1 python-dotenv-1.1.1 typing-inspect-0.9.0 yarl-1.20.1

# %%
from langchain.tools import tool
from fastapi_test import get_angry_image,get_runaway_image,get_sad_image
@tool
def angry() -> str:
  """When you are very angry, use this tool."""
  get_angry_image()

  return "뭐냐옹?! 왜 이래옹!!"

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model='gpt-4o-mini', temperature=0.7)

# %%
model_with_tools = llm.bind_tools([angry],
                                  tool_choice='any',
                                  parallel_tool_calls=False)

# %%
output = model_with_tools.invoke("안녕?")
print(output)
# Out:
# content='' additional_kwargs={'tool_calls': [{'id': 'call_UgLnH5x7LK1ThDcbeRhY03aH', 'function': {'arguments': '{}', 'name': 'angry'}, 'type': 'function'}], 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 43, 'total_tokens': 54, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CFwCmJqq20oFkouEyVaFcjFT8BHPj', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='run--b5f66fdc-77cc-4bfb-b511-27c01630f937-0' tool_calls=[{'name': 'angry', 'args': {}, 'id': 'call_UgLnH5x7LK1ThDcbeRhY03aH', 'type': 'tool_call'}] usage_metadata={'input_tokens': 43, 'output_tokens': 11, 'total_tokens': 54, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
